# %%
#import libraries
import requests
import pandas as pd
import time
print("imported")
# Out:
# imported

# %%
#Keys
API_KEY = "AIzaSyAs58nO0qSAF-8tUrZ_-hKncWvOmtr_C_A"
CHANNEL_ID = "UC-9b7aDP6ZN0coj9-xFnrtw"

# %%
#make API call
pageToken =""
url = "https://www.googleapis.com/youtube/v3/search?key="+ API_KEY + "&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+ pageToken
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'zfKZ4TyrljTgJ6heL5ae1IKaYL4',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'FR',
#  'pageInfo': {'totalResults': 341, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'TDqn7nKl3mHliCfn0YRqM_qUCBc',
#    'id': {'kind': 'youtube#video', 'videoId': 'leiqMYUOOUQ'},
#    'snippet': {'publishedAt': '2023-08-11T16:36:45Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What Scientists Snuck Onto the Voyager Probes to Make Them Last Longer',
#     'description': 'Insane (for the time) Voyager engineering. Try Speakly for free for 7 days, and get a 60% discount if you join the annual ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/leiqMYUOOUQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/leiqMYUOOUQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/leiqMYUOOUQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-11T16:36:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7ED6IUTEuaUTwCKCAYbjQj34Mm0',
#    'id': {'kind': 'youtube#video', 'videoId': 'DZI-Xmb_IKY'},
#    'snippet': {'publishedAt': '2023-08-07T21:00:05Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What Billionaires Really Want from Space | Astrum SleepSpace Podcast',
#     'description': 'Commercial space companies SpaceX, Virgin Galactic and Blue Origin comparison. A visual version of this video: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DZI-Xmb_IKY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DZI-Xmb_IKY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DZI-Xmb_IKY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-07T21:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'oAsHjJyFVk1GRJ6UEwJT5SldBE8',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ocd0ZNFuc0k'},
#    'snippet': {'publishedAt': '2023-08-03T16:14:52Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'How Star Wars Is Not a Premise Far Far Away...',
#     'description': 'Could these weapons in space that end us all? NEW Solar System Displate Posters: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ocd0ZNFuc0k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ocd0ZNFuc0k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ocd0ZNFuc0k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-08-03T16:14:52Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'D7ZoPZW0at5wg-J-2l3nDjNZKKA',
#    'id': {'kind': 'youtube#video', 'videoId': 'JGT9uU_eoPI'},
#    'snippet': {'publishedAt': '2023-07-31T21:00:09Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What 5 Tons of TNT Does to a Comet | NASA Deep Impact | Astrum SleepSpace Podcast',
#     'description': 'NASA decided to crash a spacecraft as hard as they could into Comet Tempel 1. But why? A visual version of this video: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JGT9uU_eoPI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JGT9uU_eoPI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JGT9uU_eoPI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-31T21:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gFffyTCWuhnrUkaoReqVZKiUFwg',
#    'id': {'kind': 'youtube#video', 'videoId': '3Ai3Mv_HcFg'},
#    'snippet': {'publishedAt': '2023-07-27T18:08:51Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Largest Extinction Event on Earth Was NOT Caused By a Meteor',
#     'description': 'What was Earth-like in the age of dinosaurs? Download Opera One here: https://opr.as/Opera-browser-Astrum Join us on the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3Ai3Mv_HcFg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3Ai3Mv_HcFg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3Ai3Mv_HcFg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-27T18:08:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XoybsJkIC_TDbwUQfJNiYP6B9Tw',
#    'id': {'kind': 'youtube#video', 'videoId': '6v84R8LDgx0'},
#    'snippet': {'publishedAt': '2023-07-13T18:41:45Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Parker Solar Probe Detected Something We&#39;ve Never Seen Before on the Sun&#39;s Surface',
#     'description': 'What Parker Solar Probe Heard Around the Sun. Astrum Merch! https://astrum-shop.fourthwall.com/ Join us on the Astrum discord: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6v84R8LDgx0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6v84R8LDgx0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6v84R8LDgx0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-13T18:41:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6QBlGI-z8Fhgc-JgTb719Tc9p3g',
#    'id': {'kind': 'youtube#video', 'videoId': 'q62ODdKtDm8'},
#    'snippet': {'publishedAt': '2023-07-10T17:22:42Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Are We Close To Finding Planet 9? | Astrum SleepSpace Podcast',
#     'description': 'How and why scientists are searching for Planet X / Planet Nine / Planet 9. A visual version of this video: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q62ODdKtDm8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/q62ODdKtDm8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/q62ODdKtDm8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-10T17:22:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KoAnJhtaCLXAXxQk74alLeBbNB4',
#    'id': {'kind': 'youtube#video', 'videoId': 'G1VwR0XUZYc'},
#    'snippet': {'publishedAt': '2023-07-06T18:23:50Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': '&#39;Oumuamua Is at the Heart of a Ongoing Battle Raging Within the Scientific Community... Again',
#     'description': "More dark comets have been found. Why does 'Oumuamua accelerate? Visit https://brilliant.org/astrum to sample their courses in ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/G1VwR0XUZYc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/G1VwR0XUZYc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/G1VwR0XUZYc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-06T18:23:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RVJQ1T9D9csOWqPTZy88PmTyt_s',
#    'id': {'kind': 'youtube#video', 'videoId': 'PgtnyiBvkUY'},
#    'snippet': {'publishedAt': '2023-07-03T19:06:55Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What the Polar Vortex Will Do to Earth this Decade',
#     'description': 'Everything about the Polar Vortex, Polar Night Jet, and the Jet Streams. Go to https://nautil.us/astrum and use the coupon code ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PgtnyiBvkUY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PgtnyiBvkUY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PgtnyiBvkUY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-03T19:06:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zZY7FVNUX44IcbGrbIzV6g3BL88',
#    'id': {'kind': 'youtube#video', 'videoId': '0_TuSSfIeZ8'},
#    'snippet': {'publishedAt': '2023-06-29T19:29:22Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Final Images of Tempel-1 | Deep Impact Stardust',
#     'description': 'Supercut of how NASA crashed into Tempel-1 and visited Wild-2 with the Deep Impact and Stardust probes. What other videos do ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0_TuSSfIeZ8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0_TuSSfIeZ8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0_TuSSfIeZ8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-29T19:29:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9iGkeqxaUYAqH7D3ATJa35PtjEA',
#    'id': {'kind': 'youtube#video', 'videoId': 'OyRZwe836sg'},
#    'snippet': {'publishedAt': '2023-06-23T15:39:01Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'If We Stop Using Fossil Fuels Today...',
#     'description': "Are we the last civilization on Earth? Check out Planet Wild's Deep sea clean-up: https://planetwild.com/astrum/2 Saving dying ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OyRZwe836sg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OyRZwe836sg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OyRZwe836sg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-23T15:39:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kZm_1adHRUkWM9VK7YE8VrZiCMA',
#    'id': {'kind': 'youtube#video', 'videoId': 'TfwaEhNg9Oc'},
#    'snippet': {'publishedAt': '2023-06-15T16:20:59Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Attribute of Light Science Still Can&#39;t Explain',
#     'description': 'Double slit experiment, and quantum light paradox. Get 60% off your Babbel subscription: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TfwaEhNg9Oc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TfwaEhNg9Oc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TfwaEhNg9Oc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-15T16:20:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0JoppPS9mxNjrh57UgQkycApjPo',
#    'id': {'kind': 'youtube#video', 'videoId': 'GRJ71RVWfeo'},
#    'snippet': {'publishedAt': '2023-06-08T20:34:05Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'This Is What Happens When You Let AI Study Space',
#     'description': 'Will we send AI to space? How can it help us, and even do better than us at certain tasks? Get NordVPN 2Y plan + 4 months free ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GRJ71RVWfeo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GRJ71RVWfeo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GRJ71RVWfeo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-08T20:34:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'G7HjzPcoKvw2eJpKEFYAiMYlndo',
#    'id': {'kind': 'youtube#video', 'videoId': 'wpD8xFw2CAw'},
#    'snippet': {'publishedAt': '2023-06-01T16:19:49Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'I Never Knew the Centre of the Galaxy Looked So Amazing | VLT',
#     'description': 'How the Very Large Telescope works and how its discoveries about Sagittarius A* lead to a Nobel Physics Prize. Get a razor that ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wpD8xFw2CAw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wpD8xFw2CAw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wpD8xFw2CAw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-01T16:19:49Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FceJuMnm_1Scc2l25z9FJkuqqBc',
#    'id': {'kind': 'youtube#video', 'videoId': 'dPUHMStpfqo'},
#    'snippet': {'publishedAt': '2023-05-26T17:03:56Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Bizarre Creatures that Lived on Earth Before the Dinosaurs',
#     'description': 'How did Earth become habitable? Join us on a journey through time. Ground News Sale: Compare news coverage. Spot media ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dPUHMStpfqo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dPUHMStpfqo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dPUHMStpfqo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-26T17:03:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6-1eEorf1RmId1Y8MqBktcgUDQc',
#    'id': {'kind': 'youtube#video', 'videoId': 'fiG5g7XvczU'},
#    'snippet': {'publishedAt': '2023-05-18T19:13:57Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'This Makes Me Angry: the Mysterious Explosion on the Moon Shouldn&#39;t Have Happened',
#     'description': 'The implications of the 2022 rocket booster collision with the Moon. Get a beautiful metal poster of your favourite planet for your ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fiG5g7XvczU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fiG5g7XvczU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fiG5g7XvczU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-18T19:13:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PU8xWkyaH5PnAnh4n2ldfdXG4yQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'U75blaWkIrQ'},
#    'snippet': {'publishedAt': '2023-05-15T14:57:18Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Something Unprecedented Is Happening Inside Saturn, and This Is Our Best Guess Why | CASSINI',
#     'description': 'New NASA Cassini data shows that Saturn is not the world we once thought it was... Get NordVPN 2Y plan + 4 months free here ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U75blaWkIrQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U75blaWkIrQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U75blaWkIrQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-15T14:57:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '60lulJWoJH3GBPTeMmwU38Vpung',
#    'id': {'kind': 'youtube#video', 'videoId': 'WzC92VJJnvg'},
#    'snippet': {'publishedAt': '2023-05-10T16:12:21Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Universe As You Know It Does Not Exist. Let me explain with a graph...',
#     'description': "The Unseen World supercut. How big is the universe? What's at the edge? Why does light have a speed limit? What other videos ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WzC92VJJnvg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WzC92VJJnvg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WzC92VJJnvg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-10T16:12:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'f-JQlBe_WDmL3SOZW4RomiF-nZ0',
#    'id': {'kind': 'youtube#video', 'videoId': 'mggRl80WzbE'},
#    'snippet': {'publishedAt': '2023-05-05T21:20:58Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What El Niño Will do to Earth in 2024',
#     'description': 'The La Niña and El Niño Southern Oscillation. Visit https://brilliant.org/astrum to sample their courses in a 30-day free trial + the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mggRl80WzbE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mggRl80WzbE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mggRl80WzbE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-05T21:20:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZkLdr8dNjayCvRijZsFMZqbBMHw',
#    'id': {'kind': 'youtube#video', 'videoId': 'pJ5L6hLD4KU'},
#    'snippet': {'publishedAt': '2023-04-27T16:45:04Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Where AVATAR Went Wrong - Astrum&#39;s Take on Planet Pandora',
#     'description': 'A scientific perspective on the Avatar movies. Skip the waitlist and invest with Masterworks here: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pJ5L6hLD4KU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pJ5L6hLD4KU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pJ5L6hLD4KU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-27T16:45:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jdKv_DbgR1n1I76xO1hptfTQLCE',
#    'id': {'kind': 'youtube#video', 'videoId': 'HDWb2rK72kk'},
#    'snippet': {'publishedAt': '2023-04-20T16:10:50Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Most Exciting Probe that No-one is Talking About | ESA JUICE Jupiter Icy Moons Explorer',
#     'description': "ESA JUICE's launch and how it was made. Get NordVPN 2Y plan + 4 months free here ➼ https://nordvpn.com/astrum It's risk-free ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HDWb2rK72kk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HDWb2rK72kk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HDWb2rK72kk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-20T16:10:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'x8SnLr-Sre_aM-uT8rqAYYeYxO0',
#    'id': {'kind': 'youtube#video', 'videoId': '6FPk3sLssPQ'},
#    'snippet': {'publishedAt': '2023-04-14T16:52:31Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Experiment that Proved Einstein&#39;s Quantum Theory Wrong | Quantum Eraser',
#     'description': 'Can you travel backwards in time? Quantum Eraser experiment says yes. Play Warframe for free now and the Duviri Paradox ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6FPk3sLssPQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6FPk3sLssPQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6FPk3sLssPQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-14T16:52:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SoPpxERP27R7o9RNmxsCBvrIl1A',
#    'id': {'kind': 'youtube#video', 'videoId': 'cMv2dCjcfvo'},
#    'snippet': {'publishedAt': '2023-04-06T15:21:53Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What&#39;s Inside the Heart of the Small Magellanic Cloud | JWST Discoveries Part 2',
#     'description': 'The discoveries James Webb has made beyond the visible light spectrum. Join the official Astrum discord server plus a host of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cMv2dCjcfvo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cMv2dCjcfvo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cMv2dCjcfvo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-06T15:21:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'u4vXTpet1zD8Gd1TgEet_XwLSNw',
#    'id': {'kind': 'youtube#video', 'videoId': 'dubeUQzk7D0'},
#    'snippet': {'publishedAt': '2023-03-31T16:03:51Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What&#39;s ACTUALLY Preventing Us From Colonising the Solar System RIGHT NOW',
#     'description': 'Evolution is slow. What if we get the power to take matters into our own hands? Thanks to Scopely for sponsoring this video ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dubeUQzk7D0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dubeUQzk7D0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dubeUQzk7D0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-31T16:03:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jxLOTHyAvD3hEr4p8V4gbvTOG1Y',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PL2gLpWRK0QlDLSz1KpaCqiEPSZML_MTlv'},
#    'snippet': {'publishedAt': '2023-03-31T12:20:17Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Sleep Space',
#     'description': 'Want to learn while falling asleep? This podcast takes the information from Astrum episodes and presents them in a brand-new, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DZI-Xmb_IKY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DZI-Xmb_IKY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DZI-Xmb_IKY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-31T12:20:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uj2xScEZzIC6U2a48q7J5Xo77zU',
#    'id': {'kind': 'youtube#video', 'videoId': 'B588JHKSlEE'},
#    'snippet': {'publishedAt': '2023-03-28T15:18:58Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What They Didn&#39;t Teach You at School about Planet Mercury | NASA&#39;s MESSENGER Discoveries',
#     'description': 'Everything you could want to know about Mercury, from its craters, to its history and geology - plus a look into its most bizarre ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/B588JHKSlEE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/B588JHKSlEE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/B588JHKSlEE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-28T15:18:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zUQ4z9cPyjxDmwPT-oWkMnsyd-Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'FklQHcbU8pc'},
#    'snippet': {'publishedAt': '2023-03-23T17:21:37Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Only Instance Where Rainbows Are Upside Down | Weird Atmospheric Phenomena',
#     'description': 'Supralateral arcs, ice pillars and sun pillars. For beautiful meteorite rings and more, check out https://www.thorum.com and use ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FklQHcbU8pc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FklQHcbU8pc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FklQHcbU8pc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-23T17:21:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PnCnSiB1ojmbBsclW6O6lApFLPg',
#    'id': {'kind': 'youtube#video', 'videoId': 'otPxviO_SCA'},
#    'snippet': {'publishedAt': '2023-03-17T16:25:44Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Multiple US NAVY Sensors Detected Something &quot;Impossible&quot; | Scientifically Authenticated UFOs',
#     'description': 'What are these objects in our skies? Go to https://curiositystream.com/ASTRUM and use code ASTRUM to save 25% off today.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/otPxviO_SCA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/otPxviO_SCA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/otPxviO_SCA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-17T16:25:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0iHibBqguxFINrlIDuUZb-wPPGg',
#    'id': {'kind': 'youtube#video', 'videoId': 'IYvaIFk3nwA'},
#    'snippet': {'publishedAt': '2023-03-10T15:46:30Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Hidden Side of Pluto Revealed | New Horizons',
#     'description': "What's happening over and under Pluto's fascinating surface. Skip the waitlist and invest with Masterworks here: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IYvaIFk3nwA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IYvaIFk3nwA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IYvaIFk3nwA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-10T15:46:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'byAF-xXIhKZS-L9P-S-GGOWzWIc',
#    'id': {'kind': 'youtube#video', 'videoId': 'ptpPHgz9DU0'},
#    'snippet': {'publishedAt': '2023-03-02T21:12:02Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What South Korea Saw in the Darkest Regions on the Moon | DANURI and NASA&#39;s LRO',
#     'description': 'A look at permanently shadowed regions on the Moon where NASA and KARI hopes to find water ice. Use ASTRUM20 code to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ptpPHgz9DU0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ptpPHgz9DU0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ptpPHgz9DU0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-02T21:12:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 't2Ycdu79CjMQn4qca4Z1OkVu41M',
#    'id': {'kind': 'youtube#video', 'videoId': 'e7oLtaZIVaE'},
#    'snippet': {'publishedAt': '2023-02-25T16:00:31Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'NASA&#39;s Voyager 1 Journey Through Space',
#     'description': 'shorts Voyager 1 has traveled further than any human invention has gone before. Currently, 23.8 billion km from Earth, watch this ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/e7oLtaZIVaE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/e7oLtaZIVaE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/e7oLtaZIVaE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-25T16:00:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'oHh-APbW8k-l6FpH4TbwjYnVauI',
#    'id': {'kind': 'youtube#video', 'videoId': '-aFaOiZdqJk'},
#    'snippet': {'publishedAt': '2023-02-23T17:46:00Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Could We Be Detecting the Effects of &quot;Hyperdrive&quot; Travel? | More Wow Signals',
#     'description': 'The most intriguing signals SETI ever detected - SHGb02+14a, BLC1 and fast radio bursts. Compare news coverage. Spot media ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-aFaOiZdqJk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-aFaOiZdqJk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-aFaOiZdqJk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-23T17:46:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bwrMP3U2ITXTbluGZsQjcBKhTmY',
#    'id': {'kind': 'youtube#video', 'videoId': 'EXYiUh6AKFw'},
#    'snippet': {'publishedAt': '2023-02-20T17:02:25Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Why These Rocks on Mars Shocked Perseverance Scientists the Most | 1st Year Supercut',
#     'description': "Everything NASA's Perseverance saw and discovered during its first year on Mars. Astrum merch now available! Apparel: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EXYiUh6AKFw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EXYiUh6AKFw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EXYiUh6AKFw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-20T17:02:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Cid-tOUtvl6NqsbC2rBUMOe3x40',
#    'id': {'kind': 'youtube#video', 'videoId': 'hJ0PajyW-pM'},
#    'snippet': {'publishedAt': '2023-02-18T16:00:20Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'How Our Moon Wobbles in the Sky',
#     'description': "shorts I bet you didn't know the moon did this. This video shows the path of our lunar moon over the course of a month. Stick until ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hJ0PajyW-pM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hJ0PajyW-pM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hJ0PajyW-pM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-18T16:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OAlLGmkrDzzqQAQj_gpasXnj6Fg',
#    'id': {'kind': 'youtube#video', 'videoId': 'f0gg1PtBp9A'},
#    'snippet': {'publishedAt': '2023-02-16T17:54:59Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Could We Be on the Verge of a Major Technological Transportation Breakthrough?',
#     'description': 'Ion Engines are the future. How far away are we from them becoming the norm? Visit https://brilliant.org/astrum to sample their ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f0gg1PtBp9A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f0gg1PtBp9A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f0gg1PtBp9A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-16T17:54:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bXLg8nD8NnI6iro491QzAFTenPs',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PL2gLpWRK0QlB6CZtvKiUI6t1pbWNjjT7O'},
#    'snippet': {'publishedAt': '2023-02-16T10:59:47Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Technology',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f0gg1PtBp9A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f0gg1PtBp9A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f0gg1PtBp9A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-16T10:59:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4UQeeeb7bPf6D9QI2ziGx8i0PgA',
#    'id': {'kind': 'youtube#video', 'videoId': 'x508b5EIrdQ'},
#    'snippet': {'publishedAt': '2023-02-11T16:00:27Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'How Does The International Space Station Maintain its Orientation?',
#     'description': "shorts Have you ever wondered how the International Space Station doesn't tumble around in space like many other objects?",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x508b5EIrdQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/x508b5EIrdQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/x508b5EIrdQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-11T16:00:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cJVtIQd_xKiaWVpqugBJtiUBaKI',
#    'id': {'kind': 'youtube#video', 'videoId': 'LoSwR9GUUrY'},
#    'snippet': {'publishedAt': '2023-02-09T17:00:20Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Signal NASA Didn&#39;t Want to Receive from the LUCY Probe',
#     'description': 'Join me today in the nail-biting journey of LUCY. Use my link to install Angry Birds Friends for FREE: https://rov.io/astrum and revel ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LoSwR9GUUrY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LoSwR9GUUrY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LoSwR9GUUrY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-09T17:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'q4mqs8ZkaKuQi05L9yunAbjANAQ',
#    'id': {'kind': 'youtube#video', 'videoId': '_12LxT_VSOQ'},
#    'snippet': {'publishedAt': '2023-02-04T01:38:27Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What if the Sun Disappeared? 🌞',
#     'description': 'shorts What would happen if the sun, one day, just disappeared? Watch until the end to see what would happen. SUBSCRIBE for ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_12LxT_VSOQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_12LxT_VSOQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_12LxT_VSOQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-04T01:38:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hVKShE0m5h60zRVHwX9JKgIOg-E',
#    'id': {'kind': 'youtube#video', 'videoId': '3HPH3xpE6qA'},
#    'snippet': {'publishedAt': '2023-01-27T18:00:02Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Artemis 1&#39;s Attempt to Reclaim The Moon Blew Us Away',
#     'description': 'Everything about the Artemis 1 mission to the Moon. Compare news coverage. Spot media bias. Avoid algorithms. Be well ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3HPH3xpE6qA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3HPH3xpE6qA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3HPH3xpE6qA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-27T18:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ePF6beRR4SzLDEQdLB9YAi1gXOI',
#    'id': {'kind': 'youtube#video', 'videoId': 'MzXWGMFfwaY'},
#    'snippet': {'publishedAt': '2023-01-24T20:30:15Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Longest Tornadoes in the World?',
#     'description': "shorts What's a sideway tornado? Do they really exist? Stay until the end to learn about this strange weather phenomenon! NEW!",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MzXWGMFfwaY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MzXWGMFfwaY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MzXWGMFfwaY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-24T20:30:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KMLoPIjhl9L40XDs9g0cD4yuQf8',
#    'id': {'kind': 'youtube#video', 'videoId': 'uY4vsJNouPE'},
#    'snippet': {'publishedAt': '2023-01-16T16:05:28Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Planet Closer to the Sun than Mercury | Vulcan',
#     'description': 'because of Newtonian physics. But Albert Einstein and relativity had other ideas. Enjoy 10% off 6” and 8.5” MOVA Globes with ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uY4vsJNouPE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uY4vsJNouPE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uY4vsJNouPE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-16T16:05:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZTfg7ot_LPrMBg1BqqDs7ddU48w',
#    'id': {'kind': 'youtube#video', 'videoId': 'z6y-CIBIQfE'},
#    'snippet': {'publishedAt': '2023-01-12T17:00:28Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'This Guy Finally Makes Gravity Understandable',
#     'description': 'shorts This video explains gravity in a visual way. What do you think will happen to the balls when the teacher drops them?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/z6y-CIBIQfE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/z6y-CIBIQfE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/z6y-CIBIQfE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-12T17:00:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vpHI4M9E2zgwqpl4euJ7jjtynac',
#    'id': {'kind': 'youtube#video', 'videoId': 'aKUkFHJL-b8'},
#    'snippet': {'publishedAt': '2023-01-09T18:11:33Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'NASA&#39;s Discoveries Deep Within Jupiter&#39;s Clouds and Moons | Juno Year 6 Update',
#     'description': "NASA's Juno probe is coming to the end of a fantastic mission, but it's still got some tricks up its sleeve yet. NEW Solar System ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aKUkFHJL-b8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aKUkFHJL-b8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aKUkFHJL-b8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-09T18:11:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Was7aaS8osa27EGvMMNAGUoC7B4',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ln69789fGoQ'},
#    'snippet': {'publishedAt': '2023-01-02T18:35:12Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'The Speed of Light Reveals the Universe Must Be Stranger Than We Ever Imagined',
#     'description': "Why doesn't anything go faster than the speed of light? Want to see the world through the eyes of a scientist?",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ln69789fGoQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ln69789fGoQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ln69789fGoQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-02T18:35:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GENjsAGpWLXqnAhndbqn-dzRBUY',
#    'id': {'kind': 'youtube#video', 'videoId': 'yVAwc7SxpWk'},
#    'snippet': {'publishedAt': '2022-12-26T19:25:41Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'How the River Delta And Lake on Mars Came to Be | Perseverance Part 5',
#     'description': "NASA Perseverance's close call with Ingenuity and the start of the trip to Jezero crater. Visit https://brilliant.org/astrum to sample ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yVAwc7SxpWk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yVAwc7SxpWk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yVAwc7SxpWk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-26T19:25:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TddBfoVE6KnT-RzJ0v84HItuLFk',
#    'id': {'kind': 'youtube#video', 'videoId': 'LU89w5GVOas'},
#    'snippet': {'publishedAt': '2022-12-22T16:33:43Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'This Strange Data Received From Voyager 1 Stumped Scientists',
#     'description': "What caused Voyager I to send this weird message? Get Exclusive NordVPN deal here ➼ https://nordvpn.com/astrum It's ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LU89w5GVOas/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LU89w5GVOas/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LU89w5GVOas/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-22T16:33:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'B9ea-UxmhtcqivzlB29kxW-kx8Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'LmkRrtfY6VI'},
#    'snippet': {'publishedAt': '2022-12-19T12:33:18Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'At Last! NASA Found What it Was Looking For on Mars | InSight Probe Supercut',
#     'description': 'The entire InSight mission from start to finish, plus everything it discovered. NEW Displate Posters: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LmkRrtfY6VI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LmkRrtfY6VI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LmkRrtfY6VI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-19T12:33:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YBjnDDQWzxEnzRs_v0MhxAhsJEc',
#    'id': {'kind': 'youtube#video', 'videoId': 'Azf30mBzXZM'},
#    'snippet': {'publishedAt': '2022-12-17T17:00:15Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'Water Behaving Strangely',
#     'description': 'shorts What do you think happens when waves meet their identical counterpart? Stay until the end to find out! NEW! Displates: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Azf30mBzXZM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Azf30mBzXZM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Azf30mBzXZM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-17T17:00:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GKKW3dYpQddE5CaZm1lA3raS8KE',
#    'id': {'kind': 'youtube#video', 'videoId': '01aFP88qfQs'},
#    'snippet': {'publishedAt': '2022-12-15T16:37:38Z',
#     'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#     'title': 'What Milankovitch Cycles Will Do To Earth',
#     'description': "Earth's orbit is constantly evolving through Milankovitch Cycles. Try Speakly for free for 7 days, and get a 60% discount if you join ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/01aFP88qfQs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/01aFP88qfQs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/01aFP88qfQs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Astrum',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-15T16:37:38Z'}}]}

# %%
response ["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'TDqn7nKl3mHliCfn0YRqM_qUCBc',
#  'id': {'kind': 'youtube#video', 'videoId': 'leiqMYUOOUQ'},
#  'snippet': {'publishedAt': '2023-08-11T16:36:45Z',
#   'channelId': 'UC-9b7aDP6ZN0coj9-xFnrtw',
#   'title': 'What Scientists Snuck Onto the Voyager Probes to Make Them Last Longer',
#   'description': 'Insane (for the time) Voyager engineering. Try Speakly for free for 7 days, and get a 60% discount if you join the annual ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/leiqMYUOOUQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/leiqMYUOOUQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/leiqMYUOOUQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Astrum',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-08-11T16:36:45Z'}}

# %%
video_id = response ["items"][0]["id"]["videoId"]
video_id
# Out:
# 'leiqMYUOOUQ'

# %%
video_title = response ["items"][0]["snippet"]["title"]
video_title = str(video_title).replace("&amp;","")
video_title
# Out:
# 'What Scientists Snuck Onto the Voyager Probes to Make Them Last Longer'

# %%
upload_date = response ["items"][0]["snippet"]["publishTime"]
upload_date = str(upload_date).split("T")[0]
upload_date
# Out:
# '2023-08-11'

# %%
for video in response["items"]:
    if video ["id"]["kind"] == "youtube#video":
        video_id = video["id"]["videoId"]
        video_title = video["snippet"]["title"]
        video_title = str(video_title).replace("&amp;","")
        upload_date = video["snippet"]["publishTime"]
        upload_date = str(upload_date).split("T")[0]

        print(video_id)
        print(video_title)
        print(upload_date)
# Out:
# leiqMYUOOUQ
# What Scientists Snuck Onto the Voyager Probes to Make Them Last Longer
# 2023-08-11
# DZI-Xmb_IKY
# What Billionaires Really Want from Space | Astrum SleepSpace Podcast
# 2023-08-07
# Ocd0ZNFuc0k
# How Star Wars Is Not a Premise Far Far Away...
# 2023-08-03
# JGT9uU_eoPI
# What 5 Tons of TNT Does to a Comet | NASA Deep Impact | Astrum SleepSpace Podcast
# 2023-07-31
# 3Ai3Mv_HcFg
# The Largest Extinction Event on Earth Was NOT Caused By a Meteor
# 2023-07-27
# 6v84R8LDgx0
# Parker Solar Probe Detected Something We&#39;ve Never Seen Before on the Sun&#39;s Surface
# 2023-07-13
# q62ODdKtDm8
# Are We Close To Finding Planet 9? | Astrum SleepSpace Podcast
# 2023-07-10
# G1VwR0XUZYc
# &#39;Oumuamua Is at the Heart of a Ongoing Battle Raging Within the Scientific Community... Again
# 2023-07-06
# PgtnyiBvkUY
# What the Polar Vortex Will Do to Earth this Decade
# 2023-07-03
# 0_TuSSfIeZ8
# The Final Images of Tempel-1 | Deep Impact Stardust
# 2023-06-29
# OyRZwe836sg
# If We Stop Using Fossil Fuels Today...
# 2023-06-23
# TfwaEhNg9Oc
# The Attribute of Light Science Still Can&#39;t Explain
# 2023-06-15
# GRJ71RVWfeo
# This Is What Happens When You Let AI Study Space
# 2023-06-08
# wpD8xFw2CAw
# I Never Knew the Centre of the Galaxy Looked So Amazing | VLT
# 2023-06-01
# dPUHMStpfqo
# The Bizarre Creatures that Lived on Earth Before the Dinosaurs
# 2023-05-26
# fiG5g7XvczU
# This Makes Me Angry: the Mysterious Explosion on the Moon Shouldn&#39;t Have Happened
# 2023-05-18
# U75blaWkIrQ
# Something Unprecedented Is Happening Inside Saturn, and This Is Our Best Guess Why | CASSINI
# 2023-05-15
# WzC92VJJnvg
# The Universe As You Know It Does Not Exist. Let me explain with a graph...
# 2023-05-10
# mggRl80WzbE
# What El Niño Will do to Earth in 2024
# 2023-05-05
# pJ5L6hLD4KU
# Where AVATAR Went Wrong - Astrum&#39;s Take on Planet Pandora
# 2023-04-27
# HDWb2rK72kk
# The Most Exciting Probe that No-one is Talking About | ESA JUICE Jupiter Icy Moons Explorer
# 2023-04-20
# 6FPk3sLssPQ
# The Experiment that Proved Einstein&#39;s Quantum Theory Wrong | Quantum Eraser
# 2023-04-14
# cMv2dCjcfvo
# What&#39;s Inside the Heart of the Small Magellanic Cloud | JWST Discoveries Part 2
# 2023-04-06
# dubeUQzk7D0
# What&#39;s ACTUALLY Preventing Us From Colonising the Solar System RIGHT NOW
# 2023-03-31
# B588JHKSlEE
# What They Didn&#39;t Teach You at School about Planet Mercury | NASA&#39;s MESSENGER Discoveries
# 2023-03-28
# FklQHcbU8pc
# The Only Instance Where Rainbows Are Upside Down | Weird Atmospheric Phenomena
# 2023-03-23
# otPxviO_SCA
# Multiple US NAVY Sensors Detected Something &quot;Impossible&quot; | Scientifically Authenticated UFOs
# 2023-03-17
# IYvaIFk3nwA
# The Hidden Side of Pluto Revealed | New Horizons
# 2023-03-10
# ptpPHgz9DU0
# What South Korea Saw in the Darkest Regions on the Moon | DANURI and NASA&#39;s LRO
# 2023-03-02
# e7oLtaZIVaE
# NASA&#39;s Voyager 1 Journey Through Space
# 2023-02-25
# -aFaOiZdqJk
# Could We Be Detecting the Effects of &quot;Hyperdrive&quot; Travel? | More Wow Signals
# 2023-02-23
# EXYiUh6AKFw
# Why These Rocks on Mars Shocked Perseverance Scientists the Most | 1st Year Supercut
# 2023-02-20
# hJ0PajyW-pM
# How Our Moon Wobbles in the Sky
# 2023-02-18
# f0gg1PtBp9A
# Could We Be on the Verge of a Major Technological Transportation Breakthrough?
# 2023-02-16
# x508b5EIrdQ
# How Does The International Space Station Maintain its Orientation?
# 2023-02-11
# LoSwR9GUUrY
# The Signal NASA Didn&#39;t Want to Receive from the LUCY Probe
# 2023-02-09
# _12LxT_VSOQ
# What if the Sun Disappeared? 🌞
# 2023-02-04
# 3HPH3xpE6qA
# Artemis 1&#39;s Attempt to Reclaim The Moon Blew Us Away
# 2023-01-27
# MzXWGMFfwaY
# The Longest Tornadoes in the World?
# 2023-01-24
# uY4vsJNouPE
# The Planet Closer to the Sun than Mercury | Vulcan
# 2023-01-16
# z6y-CIBIQfE
# This Guy Finally Makes Gravity Understandable
# 2023-01-12
# aKUkFHJL-b8
# NASA&#39;s Discoveries Deep Within Jupiter&#39;s Clouds and Moons | Juno Year 6 Update
# 2023-01-09
# Ln69789fGoQ
# The Speed of Light Reveals the Universe Must Be Stranger Than We Ever Imagined
# 2023-01-02
# yVAwc7SxpWk
# How the River Delta And Lake on Mars Came to Be | Perseverance Part 5
# 2022-12-26
# LU89w5GVOas
# This Strange Data Received From Voyager 1 Stumped Scientists
# 2022-12-22
# LmkRrtfY6VI
# At Last! NASA Found What it Was Looking For on Mars | InSight Probe Supercut
# 2022-12-19
# Azf30mBzXZM
# Water Behaving Strangely
# 2022-12-17
# 01aFP88qfQs
# What Milankovitch Cycles Will Do To Earth
# 2022-12-15

# %%
video_id="01aFP88qfQs"
url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY


response_video_stats = requests.get(url_video_stats).json()

# %%
 def get_video_details(video_id): 
     #collecting view, like and comment counts
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()
        
    view_count = response_video_stats["items"][0]["statistics"]["viewCount"]
    like_count = response_video_stats["items"][0]["statistics"]["likeCount"]
    comment_count = response_video_stats ["items"][0]["statistics"]["commentCount"]

    return view_count, like_count, comment_count

# %%
def get_videos(df):

    #make API call
    pageToken =""
    url = "https://www.googleapis.com/youtube/v3/search?key="+ API_KEY + "&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+ pageToken
    response = requests.get(url).json()

    time.sleep(1)

    for video in response["items"]:
        if video ["id"]["kind"] == "youtube#video":
            video_id = video["id"]["videoId"]
            video_title = video["snippet"]["title"]
            video_title = str(video_title).replace("&amp;","")
            upload_date = video["snippet"]["publishTime"]
            upload_date = str(upload_date).split("T")[0]


            view_count, like_count, comment_count = get_video_details(video_id)
        

            #save data in pandas df
            df = df._append({"video_id":video_id, "video_title":video_title,"upload_date":upload_date,
                             "view_count":view_count,"like_count":like_count,"comment_count":comment_count}, ignore_index=True)


    return df

# %%
#main


#build our panda dataframe
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","comment_count"])

df = get_videos(df)

# %%
df.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  leiqMYUOOUQ  What Scientists Snuck Onto the Voyager Probes ...  2023-08-11
# 1  DZI-Xmb_IKY  What Billionaires Really Want from Space | Ast...  2023-08-07
# 2  Ocd0ZNFuc0k     How Star Wars Is Not a Premise Far Far Away...  2023-08-03
# 3  JGT9uU_eoPI  What 5 Tons of TNT Does to a Comet | NASA Deep...  2023-07-31
# 4  3Ai3Mv_HcFg  The Largest Extinction Event on Earth Was NOT ...  2023-07-27
#
#   view_count like_count comment_count
# 0      84529       4852           273
# 1      26797       1303           225
# 2     141284       6493           580
# 3      33274       1532            73
# 4     196354       8704           264

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","comment_count"])

# %%
df
# Out:
# Empty DataFrame
# Columns: [video_id, video_title, upload_date, view_count, like_count, comment_count]
# Index: []
